# %%
#python basics
a=int(input("enter num"))
print(10+a)
# Out:
# enter num 10
# 20

# %%
n=int(input("Enter number"))
if(n%2==0):
    print("Even")
else:
    print("Odd")
# Out:
# Enter number 13
# Odd
