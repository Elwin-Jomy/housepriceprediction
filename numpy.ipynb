# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 832.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.4 MB 951.0 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.4 MB 951.0 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.4 MB 951.0 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.4 MB 702.2 kB/s eta 0:00:17
#    --- ------------------------------------ 1.0/12.4 MB 702.2 kB/s eta 0:00:17
# ...

# %%
#1d array
import numpy as np
a=np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
#2d array
import numpy as np
a = np.array([[1,2,3],[4,5,6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#zeros
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
#ones
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
#range
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
#Random
np.random.rand(3)
# Out:
# array([0.62896964, 0.56671939, 0.87803327])
